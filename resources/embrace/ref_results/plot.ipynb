# %%
import pandas as pd
import matplotlib.pyplot as plt

df_ref = pd.read_csv(r'./sim_results.csv')
df_res = pd.read_csv(r'./../../../results/result.csv')



df_ref.columns = [x.replace("model.root.", "") for x in df_ref.columns]
df_ref = df_ref[df_ref.columns]

# print("df_res:")
# [print(x) for x in df_res.columns]
# print("df_ref:")
# [print(x) for x in df_ref.columns]

common_columns = [col for col in df_res.columns if col in df_ref.columns]

df_ref = df_ref[common_columns]
df_res = df_res[common_columns]

df_res = df_res.ffill()
df_res = df_res.sort_values("time")

# print(df_ref.head())
print(df_res.head())

df_ref.to_csv("./../../../results/ref_common.csv")
df_res.to_csv("./../../../results/res_common.csv")

# print(df_ref.columns)
# print(df_res.columns)
# Out:
#    time AdaptionUnit.Aircraft_State AdaptionUnit.LHexTout  \
# 0   0.0                           0                   273
# 1   0.1                           0    298.18526626025897
# 2   0.2                           0     298.1537742193534
# 3   0.3                           0     298.1210931572006
# 4   0.4                           0      298.089774308339
#
#     AdaptionUnit.CPUtime AdaptionUnit.EventCounter  \
# 0                2.8e-05                         4
# 1               0.002624                         5
# 2               0.030768                         6
# 3               0.032473                         7
# 4   0.034270999999999996                         8
#
#   AdaptionUnit.sWsignals.Aircraft_State AdaptionUnit.sWsignals.TLiquid  \
# 0                                     0                              0
# 1                                     0                            273
# 2                                     0             298.18526626025897
# 3                                     0              298.1537742193534
# 4                                     0              298.1210931572006
#
#              Atmos.Alt                Atmos.Ma            Atmos.CPUtime  ...  \
# 0                    0                       0   3.7999999999999995e-05  ...
# 1    3.333333333333334                   4e-04    0.0023899999999999998  ...
# 2    6.666666666666668                   8e-04                 0.030482  ...
# 3   10.000000000000002   0.0012000000000000003                 0.032171  ...
# 4   13.333333333333336                  0.0016     0.033964999999999995  ...
#
#             ECS_HW.CPUtime ECS_HW.EventCounter      ECS_HW.LHexTout  \
# 0   0.00022799999999999999                   4                  273
# 1                 0.029345                   7   298.18526626025897
# 2     0.031104999999999997                   8    298.1537742193534
# 3                 0.032909                   9    298.1210931572006
# 4                 0.035896                  10     298.089774308339
#
#   ECS_HW.consumerFeed.hn  ECS_HW.consumerFeed.m ECS_HW.consumerRet.hn  \
# 0                      0                   -0.3                     0
# 1      37088.26725137785    -0.3997042359615929    0.3193961938278211
# 2     54706.607138997584   -0.41816083812289434    1.0254358698616068
# 3      62857.69151817931    -0.4272825898347488    1.7741511670761205
# 4      67017.88044652314    -0.4282755387737121    2.4875434229233155
#
#     ECS_HW.consumerRet.m ECS_SW.Input.Aircraft_State ECS_SW.Input.TLiquid  \
# 0                    0.3                           0                    0
# 1   -0.37681915692820805                           0                  273
# 2   -0.38470106283442024                           0   298.18526626025897
# 3   -0.35997239579047485                           0    298.1537742193534
# 4   -0.33791358979328107                           0    298.1210931572006
#
#    ECS_SW.TCoolingPack
# 0                  513
# 1                  513
# 2                  513
# 3   289.76196062083375
# 4    290.5717552225776
#
# [5 rows x 49 columns]
