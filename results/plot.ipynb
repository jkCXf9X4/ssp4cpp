# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r'./result.csv')

df = df.sort_values("time")
print(df.head())

# Render the table
plt.figure(figsize=(8, 5))
for col in df.columns[1:]:
    plt.plot(df["time"], df[col], label=col)
              
plt.xlabel("time")
plt.ylabel("Values")
plt.legend()
plt.grid(True)

# Save as PNG
plt.plot()
plt.savefig("result_plot.png", dpi=300, bbox_inches="tight")
# plt.close()
# Out:
#    time  scenario.Aircraft_state  scenario.Alt  scenario.Mach  \
# 1   0.1                        0       3.33333         0.0004
# 2   0.2                        0       6.66667         0.0008
# 3   0.3                        0      10.00000         0.0012
# 4   0.4                        0      13.33330         0.0016
# 0   0.5                        0      16.66670         0.0020
#
#    scenario.Wgt_On_Whl  scenario.heat_load
# 1                    1                  50
# 2                    1                  50
# 3                    1                  50
# 4                    1                  50
# 0                    1                  50
